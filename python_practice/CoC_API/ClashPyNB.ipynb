# %%
import requests 
import pprint
import pandas as pd
import json
from pandas import json_normalize
from datetime import date


from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
headers = {
    "Accept": "*/*",
    "authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..AOb_RbLiz_ZFAyssjcK3uaYoBNnPVzbaaCibcYEBKQ-_-3Jwgm5delBsX1zAmIQn8Aa4Ubxu38PNfYtKIg8tpg"
}

def get_user():
    #return user profile information
    response = requests.get('https://api.clashofclans.com/v1/players/%23LLY09LLU', headers=headers)
    user_json = response.json()
    print(pprint.pprint(user_json))

get_user()

today = date.today()
print("Today's date:", today)
# Out:
# {'achievements': [{'completionInfo': 'Highest Gold Storage level: 13',
#                    'info': 'Upgrade a Gold Storage to level 10',
#                    'name': 'Bigger Coffers',
#                    'stars': 3,
#                    'target': 10,
#                    'value': 13,
#                    'village': 'home'},
#                   {'completionInfo': 'Stars in Campaign Map: 206',
#                    'info': 'Win 150 Stars on the Campaign Map',
#                    'name': 'Get those Goblins!',
#                    'stars': 3,
#                    'target': 150,
#                    'value': 206,
#                    'village': 'home'},
#                   {'completionInfo': 'Current Town Hall level: 13',
#                    'info': 'Upgrade Town Hall to level 8',
#                    'name': 'Bigger & Better',
#                    'stars': 3,
#                    'target': 8,
#                    'value': 13,
#                    'village': 'home'},
# ...

# %%
response = requests.get('https://api.clashofclans.com/v1/players/%23LLY09LLU', headers=headers)
user_json = response.json()
df2 = pd.DataFrame.from_dict(user_json, orient="index")
df2
# Out:
#                                                                           0
# tag                                                               #LLY09LLU
# name                                                                  Scott
# townHallLevel                                                            13
# townHallWeaponLevel                                                       5
# expLevel                                                                179
# trophies                                                               3181
# bestTrophies                                                           3719
# warStars                                                                113
# attackWins                                                               73
# defenseWins                                                               6
# builderHallLevel                                                          9
# ...

# %%
pd.set_option('display.max_columns', None)

df2_transposed = df2.T
df2_transposed
# Out:
#          tag   name townHallLevel townHallWeaponLevel expLevel trophies  \
# 0  #LLY09LLU  Scott            13                   5      179     3181
#
#   bestTrophies warStars attackWins defenseWins builderHallLevel  \
# 0         3719      113         73           6                9
#
#   versusTrophies bestVersusTrophies versusBattleWins      role warPreference  \
# 0           3442               3721             1851  coLeader           out
#
#   donations donationsReceived clanCapitalContributions  \
# 0      3957              1339                   486453
#
#                                                 clan  \
# 0  {'tag': '#2G0R0PU2C', 'name': 'Active Only', '...
#
#                                               league  \
# 0  {'id': 29000015, 'name': 'Master League I', 'i...
#
#                                         achievements  \
# 0  [{'name': 'Bigger Coffers', 'stars': 3, 'value...
#
#                                          playerHouse versusBattleWinCount  \
# ...

# %%
df2_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tag                       1 non-null      object
#  1   name                      1 non-null      object
#  2   townHallLevel             1 non-null      object
#  3   townHallWeaponLevel       1 non-null      object
#  4   expLevel                  1 non-null      object
#  5   trophies                  1 non-null      object
#  6   bestTrophies              1 non-null      object
#  7   warStars                  1 non-null      object
#  8   attackWins                1 non-null      object
#  9   defenseWins               1 non-null      object
#  10  builderHallLevel          1 non-null      object
#  11  versusTrophies            1 non-null      object
#  12  bestVersusTrophies        1 non-null      object
# ...

# %%
name = df2_transposed['name']
townHallLevel = df2_transposed['townHallLevel']
townHallWeaponLevel = df2_transposed['townHallWeaponLevel']
expLevel = df2_transposed['expLevel']
trophies = df2_transposed['trophies']
bestTrophies = df2_transposed['bestTrophies']
warStars = df2_transposed['warStars']
attackWins = df2_transposed['attackWins']
defenseWins = df2_transposed['defenseWins']
builderHallLevel = df2_transposed['builderHallLevel']
versusTrophies = df2_transposed['versusTrophies']
bestVersusTrophies = df2_transposed['bestVersusTrophies']
versusBattleWins = df2_transposed['versusBattleWins']
role = df2_transposed['role']
warPreference = df2_transposed['warPreference']
donations = df2_transposed['donations']
donationsReceived = df2_transposed['donationsReceived']
clanCapitalContributions = df2_transposed['clanCapitalContributions']
versusBattleWinCount = df2_transposed['versusBattleWinCount']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ax = df2_transposed.plot(x="name", y=["bestTrophies", "trophies"], kind="bar", rot=0, figsize=(12,9))
ax.set_xlabel("Name")
ax.set_ylabel("Trophies")
ax.legend(["Best Trophies", "Current Trophies"])
ax.title(f"Best Trophies vs Current Trophies for {name} as of:  {today}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2972/3242334802.py in <module>
#       3 ax.set_ylabel("Trophies")
#       4 ax.legend(["Best Trophies", "Current Trophies"])
# ----> 5 ax.title(f"Best Trophies vs Current Trophies for {name} as of:  {today}")
#
# TypeError: 'Text' object is not callable

# %%
df = pd.DataFrame({"subscription_type" : np.random.choice(["Subscriber","Customer"], size=240),
                   "weekday" : np.random.randint(1,8,size=240),
                   "start_year" : np.ones(240)*2013 })

gr =df.groupby(['subscription_type','weekday'])['start_year'].size().reset_index(name="Count")

piv = pd.pivot_table(gr,  values='Count',  columns=['subscription_type'],  
                         index = "weekday", aggfunc=np.sum,  fill_value=0)

piv.plot(kind="bar")

plt.show()
