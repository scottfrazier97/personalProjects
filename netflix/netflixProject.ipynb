# %% [markdown]
# # hit ESC and then M for markdown cell, or ESC and then Y for code cell

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as datetime
import numpy as np
import scipy.stats as scipy
import seaborn as sns

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
flixFile = "Resources/netflix_titles-copy.csv"

# %%
netflixDF = pd.read_csv(flixFile)
netflixDF
# Out:
#          type                                    title           director  \
# 0     TV Show                                       3%                NaN
# 1       Movie                                     7:19  Jorge Michel Grau
# 2       Movie                                    23:59       Gilbert Chan
# 3       Movie                                        9        Shane Acker
# 4       Movie                                       21     Robert Luketic
# ...       ...                                      ...                ...
# 7782    Movie                                     Zozo        Josef Fares
# 7783    Movie                                   Zubaan        Mozez Singh
# 7784    Movie                        Zulu Man in Japan                NaN
# 7785  TV Show                    Zumbo's Just Desserts                NaN
# 7786    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                    cast  \
# ...

# %%
# quick glance at the first five rows of the data
netflixDF.head()
# Out:
#       type  title           director  \
# 0  TV Show     3%                NaN
# 1    Movie   7:19  Jorge Michel Grau
# 2    Movie  23:59       Gilbert Chan
# 3    Movie      9        Shane Acker
# 4    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 1  23-Dec-16          2016  TV-MA     93 min
# 2  20-Dec-18          2011      R     78 min
# 3  16-Nov-17          2009  PG-13     80 min
# 4   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
# quick glance at the last five rows of the data
netflixDF.tail()
# Out:
#          type                                    title     director  \
# 7782    Movie                                     Zozo  Josef Fares
# 7783    Movie                                   Zubaan  Mozez Singh
# 7784    Movie                        Zulu Man in Japan          NaN
# 7785  TV Show                    Zumbo's Just Desserts          NaN
# 7786    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...  19-Oct-20
# 7783                                              India   2-Mar-19
# ...

# %%
#check the memory usage for each column
netflixDF.memory_usage(deep=True)
# Out:
# Index               128
# type             487614
# title            587840
# director         475263
# cast            1311039
# country          521480
# release_year      62296
# rating           481120
# duration         498746
# genre            703545
# description     1717639
# dtype: int64

# %%
# sorting the dataframe by specific value
netflixDF.sort_values(by='country', inplace=True)
netflixDF
# Out:
#          type                            title            director  \
# 4746    Movie                Palermo Hollywood       Eduardo Pinto
# 1221  TV Show  Carmel: Who Killed Maria Marta?  Alejandro Hartmann
# 4220  TV Show          Monzón: A Knockout Blow                 NaN
# 4102  TV Show                      Millennials                 NaN
# 4027    Movie           Memories of a Teenager     Lucas Santa Ana
# ...       ...                              ...                 ...
# 7739    Movie                  Your Excellency      Funke Akindele
# 7746  TV Show                     دفعة القاهرة                 NaN
# 7765    Movie                        Zero Hour    Robert O. Peters
# 7777  TV Show                      Zombie Dumb                 NaN
# 7784    Movie                Zulu Man in Japan                 NaN
#
#                                                    cast    country  \
# 4746  Brian Maya, Matías Desiderio, Manuela Pal, Azu...  Argentina
# ...

# %%
# identify null values, and incomplete rows
netflixDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          7787 non-null   object
#  1   title         7787 non-null   object
#  2   director      5398 non-null   object
#  3   cast          7069 non-null   object
#  4   country       7280 non-null   object
#  5   release_year  7787 non-null   int64
#  6   rating        7780 non-null   object
#  7   duration      7787 non-null   object
#  8   genre         7787 non-null   object
#  9   description   7787 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 608.5+ KB

# %%
#Shows quick statistical information regarding NUMERICAL columns in dataframe
netflixDF.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
#Number of rows and columns in dataframe
netflixDF.shape
# Out:
# (7787, 11)

# %%
#Full list of all columns in dataframe
netflixDF.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %%
#Show value counts of each value
count = netflixDF["country"].value_counts()
count
# Out:
# United States                                           2555
# India                                                    923
# United Kingdom                                           397
# Japan                                                    226
# South Korea                                              183
#                                                         ...
# Ireland, United Kingdom, Greece, France, Netherlands       1
# Sweden, United Kingdom, Finland                            1
# Norway, Denmark, Netherlands, Sweden                       1
# United Kingdom, United States, Morocco                     1
# United Kingdom, France, Belgium, United States             1
# Name: country, Length: 681, dtype: int64

# %%
#Show value counts of each value for specific column
count2 = netflixDF["type"].value_counts()
count2
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
count3 = netflixDF["rating"].value_counts()
count3
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: rating, dtype: int64

# %%
#Brings back full list of unique year values
netflixDF["release_year"].unique()
# Out:
# array([2020, 2016, 2011, 2009, 2008, 2019, 1997, 2017, 2018, 2014, 2015,
#        2010, 2005, 2013, 2012, 2006, 2000, 2003, 1989, 2004, 1977, 1971,
#        1993, 2007, 1998, 1988, 1996, 2002, 1986, 1990, 1979, 1980, 1974,
#        2001, 1999, 1966, 1991, 1982, 1994, 1995, 1978, 1992, 1972, 1975,
#        2021, 1973, 1967, 1960, 1981, 1958, 1976, 1968, 1956, 1985, 1965,
#        1984, 1983, 1987, 1945, 1946, 1962, 1925, 1942, 1969, 1955, 1963,
#        1964, 1954, 1970, 1944, 1947, 1959, 1943], dtype=int64)

# %%
#Bringing back number of unique year values
len(netflixDF["release_year"].unique())
# Out:
# 73

# %% [markdown]
# # iloc --- indexing

# %%
#Bring back specific value based on row, and column POSITION using iloc(INDEXING),
#regular loc brings back value based on STRINGS

#iloc is not used widely, because you typically will not know the exact position of what you want
dfLoc = netflixDF.iloc[3,4]
dfLoc
# Out:
# 'United States'

# %%
#Same thing as above, but quicker
netflixDF.iloc[3,4]
# Out:
# 'United States'

# %%
#Pulling back multiple columns for specific row using iloc
netflixDF.iloc[3, 3:5]
# Out:
# cast       Elijah Wood, John C. Reilly, Jennifer Connelly...
# country                                        United States
# Name: 3, dtype: object

# %% [markdown]
# # loc --- strings, booleans

# %%
netflixDF.head()
# Out:
#       type  title           director  \
# 0  TV Show     3%                NaN
# 1    Movie   7:19  Jorge Michel Grau
# 2    Movie  23:59       Gilbert Chan
# 3    Movie      9        Shane Acker
# 4    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 1  23-Dec-16          2016  TV-MA     93 min
# 2  20-Dec-18          2011      R     78 min
# 3  16-Nov-17          2009  PG-13     80 min
# 4   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
#Pull back all rows using : in the row position within brackets, and the new cols list with desired columns
cols = ["director", "rating"]

netflixDF.loc[:, cols]
# Out:
#                director rating
# 0                   NaN  TV-MA
# 1     Jorge Michel Grau  TV-MA
# 2          Gilbert Chan      R
# 3           Shane Acker  PG-13
# 4        Robert Luketic  PG-13
# ...                 ...    ...
# 7782        Josef Fares  TV-MA
# 7783        Mozez Singh  TV-14
# 7784                NaN  TV-MA
# 7785                NaN  TV-PG
# 7786           Sam Dunn  TV-MA
#
# [7787 rows x 2 columns]

# %%
#Another way of doing the above ^^^
netflixDF.loc[:, ["director", "rating"]]
# Out:
#                director rating
# 0                   NaN  TV-MA
# 1     Jorge Michel Grau  TV-MA
# 2          Gilbert Chan      R
# 3           Shane Acker  PG-13
# 4        Robert Luketic  PG-13
# ...                 ...    ...
# 7782        Josef Fares  TV-MA
# 7783        Mozez Singh  TV-14
# 7784                NaN  TV-MA
# 7785                NaN  TV-PG
# 7786           Sam Dunn  TV-MA
#
# [7787 rows x 2 columns]

# %% [markdown]
# # using a mask

# %%
#Pulling specific rows based on a conditional
netflixDF["country"] == "United States"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: country, Length: 7787, dtype: bool

# %%
#Pulling specific rows based on a conditional,
#colon in the loc is optional, brings back all rows by default
mask = netflixDF["country"] == "United States"
netflixDF.loc[mask, :]
# Out:
#        type                       title         director  \
# 3     Movie                           9      Shane Acker
# 4     Movie                          21   Robert Luketic
# 7     Movie                         187   Kevin Reynolds
# 10    Movie                        1922     Zak Hilditch
# 14    Movie                        3022       John Suits
# ...     ...                         ...              ...
# 7758  Movie  Zack and Miri Make a Porno      Kevin Smith
# 7771  Movie                        Zion       Floyd Russ
# 7774  Movie                      Zodiac    David Fincher
# 7778  Movie                  Zombieland  Ruben Fleischer
# 7781  Movie                        Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
#list comprehension + mask
mask2 = ["Movie" in x for x in netflixDF["type"]]
netflixDF.loc[mask2]
# Out:
#        type                                    title           director  \
# 1     Movie                                     7:19  Jorge Michel Grau
# 2     Movie                                    23:59       Gilbert Chan
# 3     Movie                                        9        Shane Acker
# 4     Movie                                       21     Robert Luketic
# 6     Movie                                      122    Yasir Al Yasiri
# ...     ...                                      ...                ...
# 7781  Movie                                     Zoom       Peter Hewitt
# 7782  Movie                                     Zozo        Josef Fares
# 7783  Movie                                   Zubaan        Mozez Singh
# 7784  Movie                        Zulu Man in Japan                NaN
# 7786  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                    cast  \
# ...

# %% [markdown]
# # Checking data type of column

# %%
testType = pd.DataFrame(netflixDF, columns = ["cast"])
datatypes = testType.dtypes
  
# Print the data types
# of each column
datatypes
# Out:
# cast    object
# dtype: object

# %% [markdown]
# # export data without index

# %%
#pd.to_csv(netflixDF, index=False)

# %% [markdown]
# # Cleaning data

# %%
# It is not best practice to delete columns, just make a new dataframe without it
netflixDF_sub = netflixDF.loc[:, ["type", "title", "director", "cast", "country", "release_year", "rating", "duration", "genre", "description"]]
netflixDF_sub.head()
# Out:
#       type  title           director  \
# 0  TV Show     3%                NaN
# 1    Movie   7:19  Jorge Michel Grau
# 2    Movie  23:59       Gilbert Chan
# 3    Movie      9        Shane Acker
# 4    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
# 2          2011      R     78 min
# 3          2009  PG-13     80 min
# 4          2008  PG-13    123 min
#
#                                                genre  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
#Renaming duration column

# %%
netflixDF.groupby(by="country").release_year.mean()
# Out:
# country
# Argentina                                              2016.18
# Argentina, Brazil, France, Poland, Germany, Denmark    2017.00
# Argentina, Chile                                       2017.00
# Argentina, Chile, Peru                                 2015.00
# Argentina, France                                      2017.00
#                                                         ...
# Venezuela                                              2017.00
# Venezuela, Colombia                                    2007.00
# Vietnam                                                2016.80
# West Germany                                           1977.00
# Zimbabwe                                               2017.00
# Name: release_year, Length: 681, dtype: float64

# %%
# using the datetime pandas function
dfDate = pd.DataFrame({'year': [1997, 1997, 1968],
                   'month': [4, 6, 11],
                   'day': [14, 17, 7]})
pd.to_datetime(dfDate)
# Out:
# 0   1997-04-14
# 1   1997-06-17
# 2   1968-11-07
# dtype: datetime64[ns]
